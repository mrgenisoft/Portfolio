# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline  
# %config InlineBackend.figure_format = 'png'
pd.options.display.max_columns = None

_seed = 42

# %% [markdown]
# ### Описание

# %% [markdown]
# Пример кластерного анализа по данным керна <br>
# Датасет Lindquist, 1988 скачан отсюда https://pubs.usgs.gov/of/2003/ofr-03-420/ofr-03-420.html

# %% [markdown]
# ### Списки названий столбцов

# %%
NUM_COLS = ["Depth", "Porosity", "Permeability"]
NEW_COLS1 = ["Log(Perm)"]
NEW_COLS2 = ["Log(Perm)", "RQI", "NPI", "Log(RQI)", "Log(NPI)"]

CAT_COLS = ["Bedding", "Zone"]

# %% [markdown]
# ### Чтение данных

# %%
df = pd.read_excel("poroperm.xls")
df["Porosity"] = df["Porosity"] / 100

# %%
df.head(10)
# Out:
#    Depth  Permeability  Porosity  Bedding  Zone  Well
# 0  13647          0.09     0.066        1     2     1
# 1  13650          0.13     0.088        3     2     1
# 2  13654          0.09     0.074        2     2     1
# 3  13658          1.30     0.082        3     2     1
# 4  13662          0.12     0.068        2     2     1
# 5  13727          0.07     0.081        3     3     1
# 6  13731          0.06     0.087        2     3     1
# 7  13734          0.08     0.090        3     3     1
# 8  13742          0.07     0.085        3     3     1
# 9  13747          0.04     0.103        4     3     1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1336 entries, 0 to 1335
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Depth         1336 non-null   int64
#  1   Permeability  1336 non-null   float64
#  2   Porosity      1336 non-null   float64
#  3   Bedding       1336 non-null   int64
#  4   Zone          1336 non-null   int64
#  5   Well          1336 non-null   int64
# dtypes: float64(2), int64(4)
# memory usage: 62.8 KB

# %% [markdown]
# ### Обзор данных

# %% [markdown]
# **Описательная статистика**

# %% [markdown]
# **Обзор категориальных признаков**

# %%
def countplt(df, target, feature):
    sns.countplot(x=feature, hue=target, data=df)
    plt.title(target + " vs " + feature)
    plt.legend(title=target, loc='upper right')
    plt.show()

# %%
countplt(df, "Bedding", "Zone")

# %%
countplt(df, "Well", "Zone")

# %% [markdown]
# **Обзор количественных признаков**

# %% [markdown]
# Описательная статистика

# %%
df[NUM_COLS].describe()
# Out:
#               Depth     Porosity  Permeability
# count   1336.000000  1336.000000   1336.000000
# mean   13010.647455     0.093731      7.236557
# std      766.955116     0.034494     43.942727
# min    11848.000000     0.000000      0.010000
# 25%    12338.500000     0.067000      0.050000
# 50%    12852.000000     0.089000      0.130000
# 75%    13597.500000     0.116000      1.500000
# max    14724.000000     0.195000    810.000000

# %% [markdown]
# Корреляционная матрица

# %%
corr = df[NUM_COLS].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_b8e350d0_7805_11eb_93b5_3863bba27680row0_col0,#T_b8e350d0_7805_11eb_93b5_3863bba27680row1_col1,#T_b8e350d0_7805_11eb_93b5_3863bba27680row2_col2{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b8e350d0_7805_11eb_93b5_3863bba27680row0_col1,#T_b8e350d0_7805_11eb_93b5_3863bba27680row0_col2,#T_b8e350d0_7805_11eb_93b5_3863bba27680row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_b8e350d0_7805_11eb_93b5_3863bba27680row1_col2{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_b8e350d0_7805_11eb_93b5_3863bba27680row2_col0{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_b8e350d0_7805_11eb_93b5_3863bba27680row2_col1{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }</style><table id="T_b8e350d0_7805_11eb_93b5_3863bba27680" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Depth</th>        <th class="col_heading level0 col1" >Porosity</th>        <th class="col_heading level0 col2" >Permeability</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b8e350d0_7805_11eb_93b5_3863bba27680level0_row0" class="row_heading level0 row0" >Depth</th>
#                         <td id="T_b8e350d0_7805_11eb_93b5_3863bba27680row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_b8e350d0_7805_11eb_93b5_3863bba27680row0_col1" class="data row0 col1" >-0.200419</td>
#                         <td id="T_b8e350d0_7805_11eb_93b5_3863bba27680row0_col2" class="data row0 col2" >-0.139035</td>
#             </tr>
#             <tr>
#                         <th id="T_b8e350d0_7805_11eb_93b5_3863bba27680level0_row1" class="row_heading level0 row1" >Porosity</th>
#                         <td id="T_b8e350d0_7805_11eb_93b5_3863bba27680row1_col0" class="data row1 col0" >-0.200419</td>
#                         <td id="T_b8e350d0_7805_11eb_93b5_3863bba27680row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_b8e350d0_7805_11eb_93b5_3863bba27680row1_col2" class="data row1 col2" >0.308905</td>
#             </tr>
#             <tr>
#                         <th id="T_b8e350d0_7805_11eb_93b5_3863bba27680level0_row2" class="row_heading level0 row2" >Permeability</th>
#                         <td id="T_b8e350d0_7805_11eb_93b5_3863bba27680row2_col0" class="data row2 col0" >-0.139035</td>
#                         <td id="T_b8e350d0_7805_11eb_93b5_3863bba27680row2_col1" class="data row2 col1" >0.308905</td>
#                         <td id="T_b8e350d0_7805_11eb_93b5_3863bba27680row2_col2" class="data row2 col2" >1.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Добавление нового столбца Log(Perm)

# %%
df["Log(Perm)"] = np.log(df["Permeability"])

# %%
corr = df[NUM_COLS+NEW_COLS1].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_b9049ba4_7805_11eb_9f45_3863bba27680row0_col0,#T_b9049ba4_7805_11eb_9f45_3863bba27680row1_col1,#T_b9049ba4_7805_11eb_9f45_3863bba27680row2_col2,#T_b9049ba4_7805_11eb_9f45_3863bba27680row3_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b9049ba4_7805_11eb_9f45_3863bba27680row0_col1,#T_b9049ba4_7805_11eb_9f45_3863bba27680row0_col2,#T_b9049ba4_7805_11eb_9f45_3863bba27680row0_col3,#T_b9049ba4_7805_11eb_9f45_3863bba27680row3_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_b9049ba4_7805_11eb_9f45_3863bba27680row1_col0{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_b9049ba4_7805_11eb_9f45_3863bba27680row1_col2{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_b9049ba4_7805_11eb_9f45_3863bba27680row1_col3{
#             background-color:  #de614d;
#             color:  #000000;
#         }#T_b9049ba4_7805_11eb_9f45_3863bba27680row2_col0{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_b9049ba4_7805_11eb_9f45_3863bba27680row2_col1{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_b9049ba4_7805_11eb_9f45_3863bba27680row2_col3{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_b9049ba4_7805_11eb_9f45_3863bba27680row3_col1{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_b9049ba4_7805_11eb_9f45_3863bba27680row3_col2{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }</style><table id="T_b9049ba4_7805_11eb_9f45_3863bba27680" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Depth</th>        <th class="col_heading level0 col1" >Porosity</th>        <th class="col_heading level0 col2" >Permeability</th>        <th class="col_heading level0 col3" >Log(Perm)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b9049ba4_7805_11eb_9f45_3863bba27680level0_row0" class="row_heading level0 row0" >Depth</th>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row0_col1" class="data row0 col1" >-0.200419</td>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row0_col2" class="data row0 col2" >-0.139035</td>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row0_col3" class="data row0 col3" >-0.235735</td>
#             </tr>
#             <tr>
#                         <th id="T_b9049ba4_7805_11eb_9f45_3863bba27680level0_row1" class="row_heading level0 row1" >Porosity</th>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row1_col0" class="data row1 col0" >-0.200419</td>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row1_col2" class="data row1 col2" >0.308905</td>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row1_col3" class="data row1 col3" >0.841785</td>
#             </tr>
#             <tr>
#                         <th id="T_b9049ba4_7805_11eb_9f45_3863bba27680level0_row2" class="row_heading level0 row2" >Permeability</th>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row2_col0" class="data row2 col0" >-0.139035</td>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row2_col1" class="data row2 col1" >0.308905</td>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row2_col3" class="data row2 col3" >0.433582</td>
#             </tr>
#             <tr>
#                         <th id="T_b9049ba4_7805_11eb_9f45_3863bba27680level0_row3" class="row_heading level0 row3" >Log(Perm)</th>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row3_col0" class="data row3 col0" >-0.235735</td>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row3_col1" class="data row3 col1" >0.841785</td>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row3_col2" class="data row3 col2" >0.433582</td>
#                         <td id="T_b9049ba4_7805_11eb_9f45_3863bba27680row3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Матрица точечных кросс-плотов

# %%
pd.plotting.scatter_matrix(df[NUM_COLS+NEW_COLS1], alpha=0.2)
plt.show()

# %% [markdown]
# Матрица точечных кросс-плотов в разрезе категориального признака Zone

# %%
sns.pairplot(df[NUM_COLS+NEW_COLS1+["Zone"]], hue="Zone", palette="tab10")
plt.show()

# %% [markdown]
# **Обзор количественных признаков в разрезе категориальных признаков**

# %%
sns.histplot(data=df, x="Depth", hue="Zone", element="step", palette="tab10")
plt.title("Depth vs Zone")
plt.show()

# %%
sns.scatterplot(data=df, x="Well", y="Depth", hue="Zone", palette="tab10")
plt.title("Depth vs Well")
plt.show()

# %%
sns.histplot(data=df, x="Porosity", hue="Zone", element="step", palette="tab10")
plt.title("Porosity vs Zone")
plt.show()

# %%
sns.histplot(data=df, x="Permeability", hue="Zone", element="step", log_scale=True, palette="tab10")
plt.title("Permeability vs Zone")
plt.show()

# %%
sns.histplot(data=df.loc[df["Bedding"] <= 4], x="Porosity", hue="Bedding", element="step", palette="tab10")
plt.title("Porosity vs Bedding (1-4)")
plt.show()

# %%
sns.histplot(data=df.loc[df["Bedding"] >= 5], x="Porosity", hue="Bedding", element="step", palette="tab10")
plt.title("Porosity vs Bedding (5-9)")
plt.show()

# %%
sns.histplot(data=df.loc[df["Bedding"] <= 4], x="Permeability", hue="Bedding", element="step", log_scale=True, palette="tab10")
plt.title("Permeability vs Bedding (1-4)")
plt.show()

# %%
sns.histplot(data=df.loc[df["Bedding"] >= 5], x="Permeability", hue="Bedding", element="step", log_scale=True, palette="tab10")
plt.title("Permeability vs Bedding (5-9)")
plt.show()

# %%
sns.scatterplot(data=df, x="Porosity", y="Permeability", hue="Bedding", palette="tab10")
plt.gca().set_yscale("log")
plt.title("Permeability vs Porosity")
plt.show()

# %%
sns.scatterplot(data=df, x="Porosity", y="Permeability", hue="Zone", palette="tab10")
plt.gca().set_yscale("log")
plt.title("Permeability vs Porosity")
plt.show()

# %% [markdown]
# ### Кластерный анализ методом K-средних

# %% [markdown]
# Для данного алгоритма требуется явно задавать количество кластеров (n_clusters).
# https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_k-%D1%81%D1%80%D0%B5%D0%B4%D0%BD%D0%B8%D1%85

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# Исходный массив точек

# %%
sns.scatterplot(data=df, x="Porosity", y="Permeability", palette="tab10")
plt.gca().set_yscale("log")
plt.title("Permeability vs Porosity")
plt.show()

# %% [markdown]
# Разбиение на 2 кластера по признакам Porosity и Permeability

# %%
clf = KMeans(n_clusters=2, random_state=_seed)
clf.fit(df[["Porosity", "Permeability"]])
cl_pred = clf.predict(df[["Porosity", "Permeability"]])
sns.scatterplot(data=df, x="Porosity", y="Permeability", hue=cl_pred, palette="tab10")
plt.gca().set_yscale("log")
plt.title("Permeability vs Porosity")
plt.show()

# %% [markdown]
# Разбиение на 2 кластера по признакам Porosity и Log(Perm)

# %%
clf = KMeans(n_clusters=2, random_state=_seed)
clf.fit(df[["Porosity", "Log(Perm)"]])
cl_pred = clf.predict(df[["Porosity", "Log(Perm)"]])
sns.scatterplot(data=df, x="Porosity", y="Permeability", hue=cl_pred, palette="tab10")
plt.gca().set_yscale("log")
plt.title("Permeability vs Porosity")
plt.show()

# %% [markdown]
# **Для корректного проведения кластерного анализа требуется проведение нормализации признаков.**

# %% [markdown]
# ### Нормализация

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
df_norm = pd.DataFrame(scaler.fit_transform(df[["Porosity", "Log(Perm)"]]), columns=["Porosity", "Log(Perm)"])
df_norm.describe()
# Out:
#            Porosity     Log(Perm)
# count  1.336000e+03  1.336000e+03
# mean   3.914866e-16  1.344567e-16
# std    1.000374e+00  1.000374e+00
# min   -2.718307e+00 -1.482838e+00
# 25%   -7.752358e-01 -7.722273e-01
# 50%   -1.372124e-01 -3.503431e-01
# 75%    6.458163e-01  7.294938e-01
# max    2.936900e+00  3.507393e+00

# %% [markdown]
# Разбиение на 2 кластера по нормализованным признакам Porosity и Log(Perm)

# %%
clf = KMeans(n_clusters=2, random_state=_seed)
clf.fit(df_norm)
cl_pred = clf.predict(df_norm)
sns.scatterplot(data=df, x="Porosity", y="Permeability", hue=cl_pred, palette="tab10")
plt.gca().set_yscale("log")
plt.title("Permeability vs Porosity")
plt.show()

# %% [markdown]
# Разбиение на 2 кластера по нормализованным признакам Porosity и Log(Perm)

# %%
clf = KMeans(n_clusters=3, random_state=_seed)
clf.fit(df_norm)
cl_pred = clf.predict(df_norm)
sns.scatterplot(data=df, x="Porosity", y="Permeability", hue=cl_pred, palette="tab10")
plt.gca().set_yscale("log")
plt.title("Permeability vs Porosity")
plt.show()

# %% [markdown]
# Разбиение на 10 кластеров по нормализованным признакам Porosity и Log(Perm)

# %%
clf = KMeans(n_clusters=10, random_state=_seed)
clf.fit(df_norm)
cl_pred = clf.predict(df_norm)
sns.scatterplot(data=df, x="Porosity", y="Permeability", hue=cl_pred, palette="tab10")
plt.gca().set_yscale("log")
plt.title("Permeability vs Porosity (seed=42)")
plt.show()

# %% [markdown]
# График ошибки от количества кластеров <br>
# В качестве ошибки принимается сумма квадратов растояний точек до кластерного центра (характеристика сплотченности).

# %%
err = [KMeans(n_clusters=n, random_state=_seed).fit(df_norm).inertia_ for n in range(2, 51)]
plt.plot(range(2, 51), err)
plt.title("Error vs Number of clusters")
plt.show()

# %% [markdown]
# ### Кластерный анализ по методике Flow Zone Rock Typing методом К-средних

# %%
df = df.loc[df["Porosity"] > 0, :]

# %% [markdown]
# Вычисление новых признаков NPI и RQI

# %%
df["RQI"] = 0.0314 * np.sqrt(df["Permeability"] / df["Porosity"])
df["NPI"] = df["Porosity"] / (1 - df["Porosity"])

# %%
df["Log(RQI)"] = np.log(df["RQI"])
df["Log(NPI)"] = np.log(df["NPI"])

# %%
df.head(10)
# Out:
#    Depth  Permeability  Porosity  Bedding  Zone  Well  Log(Perm)       RQI  \
# 0  13647          0.09     0.066        1     2     1  -2.407946  0.036667
# 1  13650          0.13     0.088        3     2     1  -2.040221  0.038165
# 2  13654          0.09     0.074        2     2     1  -2.407946  0.034629
# 3  13658          1.30     0.082        3     2     1   0.262364  0.125024
# 4  13662          0.12     0.068        2     2     1  -2.120264  0.041712
# 5  13727          0.07     0.081        3     3     1  -2.659260  0.029190
# 6  13731          0.06     0.087        2     3     1  -2.813411  0.026076
# 7  13734          0.08     0.090        3     3     1  -2.525729  0.029604
# 8  13742          0.07     0.085        3     3     1  -2.659260  0.028495
# 9  13747          0.04     0.103        4     3     1  -3.218876  0.019568
#
#         NPI  Log(RQI)  Log(NPI)
# 0  0.070664 -3.305870 -2.649822
# 1  0.096491 -3.265849 -2.338303
# 2  0.079914 -3.363075 -2.526809
# 3  0.089325 -2.079247 -2.415478
# 4  0.072961 -3.176955 -2.617825
# 5  0.088139 -3.533924 -2.428837
# 6  0.095290 -3.646729 -2.350828
# 7  0.098901 -3.519839 -2.313635
# 8  0.092896 -3.558025 -2.376273
# 9  0.114827 -3.933872 -2.164327

# %% [markdown]
# Корреляционная матрица

# %%
corr = df[NUM_COLS+NEW_COLS2].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col0,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row1_col1,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row1_col5,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row2_col2,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row3_col3,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row4_col4,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row5_col1,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row5_col5,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row6_col6,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row7_col7{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col1,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col2,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col3,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col4,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col5,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col6,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col7,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row3_col0,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row6_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row1_col0{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row1_col2{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row1_col3,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row3_col5{
#             background-color:  #de614d;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row1_col4{
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row1_col6,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row4_col6,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row6_col4,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row6_col5{
#             background-color:  #e97a5f;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row1_col7,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row7_col1{
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row2_col0{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row2_col1{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row2_col3{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row2_col4{
#             background-color:  #d85646;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row2_col5{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row2_col6{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row2_col7{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row3_col1{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row3_col2{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row3_col4{
#             background-color:  #ec8165;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row3_col6,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row6_col3{
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row3_col7{
#             background-color:  #e7745b;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row4_col0{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row4_col1{
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row4_col2{
#             background-color:  #d95847;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row4_col3{
#             background-color:  #ec7f63;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row4_col5{
#             background-color:  #f6bda2;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row4_col7{
#             background-color:  #efcfbf;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row5_col0{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row5_col2{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row5_col3{
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row5_col4{
#             background-color:  #f7bca1;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row5_col6{
#             background-color:  #e9785d;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row5_col7,#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row7_col5{
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row6_col1{
#             background-color:  #eb7d62;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row6_col2{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row6_col7{
#             background-color:  #f29072;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row7_col0{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row7_col2{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row7_col3{
#             background-color:  #e57058;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row7_col4{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_dbe8e3dd_7805_11eb_89c4_3863bba27680row7_col6{
#             background-color:  #f18d6f;
#             color:  #000000;
#         }</style><table id="T_dbe8e3dd_7805_11eb_89c4_3863bba27680" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Depth</th>        <th class="col_heading level0 col1" >Porosity</th>        <th class="col_heading level0 col2" >Permeability</th>        <th class="col_heading level0 col3" >Log(Perm)</th>        <th class="col_heading level0 col4" >RQI</th>        <th class="col_heading level0 col5" >NPI</th>        <th class="col_heading level0 col6" >Log(RQI)</th>        <th class="col_heading level0 col7" >Log(NPI)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dbe8e3dd_7805_11eb_89c4_3863bba27680level0_row0" class="row_heading level0 row0" >Depth</th>
#                         <td id="T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col1" class="data row0 col1" >-0.201168</td>
#                         <td id="T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col2" class="data row0 col2" >-0.139048</td>
#                         <td id="T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col3" class="data row0 col3" >-0.235776</td>
#                         <td id="T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col4" class="data row0 col4" >-0.214240</td>
#                         <td id="T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col5" class="data row0 col5" >-0.203964</td>
#                         <td id="T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col6" class="data row0 col6" >-0.233992</td>
#                         <td id="T_dbe8e3dd_7805_11eb_89c4_3863bba27680row0_col7" class="data row

# %% [markdown]
# Исходный массив точек

# %%
sns.scatterplot(data=df, x="NPI", y="RQI", palette="tab10")
plt.gca().set_xscale("log")
plt.gca().set_yscale("log")
plt.title("RQI vs NPI")
plt.show()

# %% [markdown]
# Нормализация признаков

# %%
scaler = StandardScaler()
df_norm = pd.DataFrame(scaler.fit_transform(df[["Log(RQI)", "Log(NPI)"]]), columns=["Log(RQI)", "Log(NPI)"])
df_norm.describe()
# Out:
#            Log(RQI)      Log(NPI)
# count  1.335000e+03  1.335000e+03
# mean   2.079069e-16  7.180274e-16
# std    1.000375e+00  1.000375e+00
# min   -1.965403e+00 -3.574880e+00
# 25%   -7.702296e-01 -7.037174e-01
# 50%   -3.573479e-01  2.769354e-02
# 75%    7.179029e-01  7.287689e-01
# max    3.744888e+00  2.185441e+00

# %% [markdown]
# Разбиение на 2 кластера по нормализованным признакам Log(RQI) и Log(NPI)

# %%
clf = KMeans(n_clusters=2, random_state=_seed)
clf.fit(df_norm)
cl_pred = clf.predict(df_norm)
sns.scatterplot(data=df, x="NPI", y="RQI", hue=cl_pred, palette="tab10")
plt.gca().set_xscale("log")
plt.gca().set_yscale("log")
plt.title("RQI vs NPI")
plt.show()

# %% [markdown]
# Результат разбиения на 2 кластера на исходном графике Porosity vs Permeability

# %%
sns.scatterplot(data=df, x="Porosity", y="Permeability", hue=cl_pred, palette="tab10")
plt.gca().set_yscale("log")
plt.title("Permeability vs Porosity")
plt.show()

# %% [markdown]
# График ошибки от количества кластеров <br>
# В качестве ошибки принимается сумма квадратов растояний точек до кластерного центра (характеристика сплотченности).

# %%
err = [KMeans(n_clusters=n, random_state=_seed).fit(df_norm).inertia_ for n in range(2, 51)]
plt.plot(range(2, 51), err)
plt.title("Error vs Number of clusters")
plt.show()

# %% [markdown]
# **Таким образом, приведен пример предварительной обработки признаков и кластерного анализа методом К-средних. <br>
# Пример нельзя рассматривать в качестве решения реальной задачи.**
